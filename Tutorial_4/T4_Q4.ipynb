# %% [markdown]
# ### Tutorial 4 problem 4
#
# ![image.png](attachment:fe823df1-70a4-4f9a-ad18-778484b5a5b5.png)

# %%
import numpy as np

# %%
from numpy.linalg import inv

# %% [markdown]
# This imports the inv function from the numpy.linalg module, which is used to compute the inverse of a matrix.

# %%
X = np.array([[1, 0, 1, 0], [1, -1, 1, -1], [1,1,0,0]])

# %% [markdown]
# This creates a 3x4 matrix X:

# %%
y = np.array([[1], [0], [1]])
y
# Out:
# array([[1],
#        [0],
#        [1]])

# %% [markdown]
# This creates a vector y representing the target values:

# %%
w1 = X.T @ inv(X @ X.T) @y
print(w1)
# Out:
# [[0.5]
#  [0.5]
#  [0.5]
#  [0.5]]

# %% [markdown]
# This line computes the least squares solution for sw, using the following formula:

# %%
# Another method
from numpy.linalg import pinv
w2 = pinv(X) @ y
print(w2)
# Out:
# [[0.5]
#  [0.5]
#  [0.5]
#  [0.5]]
